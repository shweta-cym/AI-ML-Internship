# %% [markdown]
# <a href="https://colab.research.google.com/github/shweta-cym/AI-ML-Internship/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scapy

# %%
from scapy.all import sniff

def packet_callback(packet):
    print(packet.summary())

print("Starting Packet Capture...")

sniff(prn=packet_callback, count=5)
# Out:
# Starting Packet Capture...
# Ether / IP / TCP 172.28.0.12:8080 > 172.28.0.1:53986 PA / Raw
# Ether / IP / TCP 172.28.0.1:53986 > 172.28.0.12:8080 A
# Ether / IP / TCP 172.28.0.12:8080 > 172.28.0.1:53986 PA / Raw
# Ether / IP / TCP 172.28.0.1:53986 > 172.28.0.12:8080 A
# Ether / IP / TCP 172.28.0.1:38322 > 172.28.0.12:8080 S
# <Sniffed: TCP:5 UDP:0 ICMP:0 Other:0>

# %% [markdown]
# from scapy.all import sniff
#
# def packet_callback(packet):
#     print(packet.summary())
#
# print("Starting Packet Capture...")
#
# sniff(prn=packet_callback, count=5)
